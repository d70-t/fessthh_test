# %%
# %matplotlib inline
import xarray as xr

# %%
ds = xr.open_dataset("https://icdc.cen.uni-hamburg.de/thredds/dodsC/ftpthredds/fessthh2020/DATA/APOLLO/08/28/fessthh_uhh_apollo_l2_ta_v00_20200828000000.nc")

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:       (nv: 2, station: 82, time: 86400)
# Coordinates:
#   * time          (time) datetime64[ns] 2020-08-28 ... 2020-08-28T23:59:59
# Dimensions without coordinates: nv, station
# Data variables:
#     time_bnds     (time, nv) datetime64[ns] ...
#     station_id    (station) |S64 ...
#     station_name  (station) |S64 ...
#     lat           (station) float32 ...
#     lon           (station) float32 ...
#     zsl           (station) float32 ...
#     zag           (station) float32 ...
#     lcz           (station) |S64 ...
#     ta            (time, station) float32 ...
# Attributes: (12/14)
#     _NCProperties:                   version=2,netcdf=4.7.3,hdf5=1.10.4
#     Title:                           Air temperature observed by APOLLO stati...
#     Institution:                     Meteorological Institute, University of ...
#     Contact_Person:                  Prof. Dr. Felix Ament (felix.ament@uni-h...
# ...

# %%
ds.ta.isel(station=1).plot()
